# %% [markdown]
# <a href="https://colab.research.google.com/github/yadavrishikesh/Deep-Learning-Slides-Code/blob/main/code/NNs/NNs_for_classification_using_tensorflow_package.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Neural Networks for Classification with TensorFlow/Keras
# **Author:** Rishikesh Yadav
#
# This notebook demonstrates how to build, train, evaluate, and visualize a simple neural network for binary classification using TensorFlow/Keras. The workflow closely follows the structure of the original classification example, but uses TensorFlow.
#
# ---
# ## TensorFlow / Keras Model Building: A Comprehensive Guide
#
# ## 1. Ways to Build Models in TensorFlow (tf.keras)
#
# TensorFlow provides **three main APIs** for defining neural network models.
#
# ### 1.1 Sequential API
#
# Used for **linear stacks of layers**.
#
# ```python
# model = keras.Sequential([
#     keras.layers.Input(shape=(2,)),
#     keras.layers.Dense(10, activation='sigmoid'),
#     keras.layers.Dense(1, activation='sigmoid')
# ])
# ```
#
# **Characteristics**:
#
# * Simple and readable
# * Layers stacked one after another
# * Cannot handle multiple inputs/outputs
# * Cannot handle non-linear graph structures
#
#
# ### 1.2 Functional API
#
# Used for **complex architectures**.
#
# ```python
# inputs = keras.Input(shape=(2,))
# x = keras.layers.Dense(10, activation='relu')(inputs)
# outputs = keras.layers.Dense(1, activation='sigmoid')(x)
# model = keras.Model(inputs, outputs)
# ```
#
# **Characteristics**:
#
# * Supports multiple inputs and outputs
# * Enables skip connections and shared layers
# * Graph-based representation
#
# ### 1.3 Model Subclassing
#
# Used for **full customization**.
#
# ```python
# class MyModel(keras.Model):
#     def __init__(self):
#         super().__init__()
#         self.d1 = keras.layers.Dense(10, activation='relu')
#         self.d2 = keras.layers.Dense(1, activation='sigmoid')
#
#     def call(self, inputs):
#         x = self.d1(inputs)
#         return self.d2(x)
#
# model = MyModel()
# ```
#
# **Characteristics**:
#
# * Maximum flexibility
# * Full control over forward pass
# * Harder to debug and visualize
#
#
# ## 2. Input Layer Options
#
# ```python
# keras.layers.Input(
#     shape=(d,),
#     dtype='float32',
#     name='input_layer'
# )
# ```
#
# * `shape`: feature dimensions (excluding batch size)
# * `dtype`: data type
# * `name`: optional identifier
#
#
# ## 3. Dense (Fully Connected) Layer
#
# ```python
# keras.layers.Dense(
#     units,
#     activation=None,
#     use_bias=True,
#     kernel_initializer='glorot_uniform',
#     bias_initializer='zeros',
#     kernel_regularizer=None,
#     bias_regularizer=None,
#     activity_regularizer=None
# )
# ```
#
#
# $$ z = W x + b $$
# $$ a = f(z) $$
#
# ## 4. Activation Functions
#
# ### Common Activations
#
# | Activation | Expression                           |
# | ---------- | ------------------------------------ |
# | Sigmoid    | $$\sigma(z)=\frac{1}{1+e^{-z}}$$     |
# | Tanh       | $$\tanh(z)$$                         |
# | ReLU       | $$\max(0,z)$$                        |
# | LeakyReLU  | $$\max(\alpha z, z)$$                |
# | ELU        | $$z \text{ if } z>0, \alpha(e^z-1)$$ |
# | Softmax    | $$\frac{e^{z_i}}{\sum_j e^{z_j}}$$   |
# | Linear     | $$z$$                                |
#
# ```python
# activation='relu'
# activation='sigmoid'
# activation=keras.layers.LeakyReLU(alpha=0.01)
# ```
#
#
# ## 5. Output Layer Choices
#
# ### Binary Classification
#
# ```python
# Dense(1, activation='sigmoid')
# ```
#
# ### Multiclass Classification
#
# ```python
# Dense(K, activation='softmax')
# ```
#
# ### Regression
#
# ```python
# Dense(1, activation='linear')
# ```
#
# ## 6. Loss Functions
#
# ### Classification Losses
#
# * Binary Cross-Entropy:
#
# $$ L = -[y \log(\hat y) + (1-y) \log(1-\hat y)] $$
#
# ```python
# loss='binary_crossentropy'
# ```
#
# * Categorical Cross-Entropy:
#
# ```python
# loss='categorical_crossentropy'
# ```
#
# * Sparse Categorical Cross-Entropy:
#
# ```python
# loss='sparse_categorical_crossentropy'
# ```
#
# ### Regression Losses
#
# * Mean Squared Error:
#
# $$ L = \frac{1}{N} \sum (y - \hat y)^2 $$
#
# ```python
# loss='mse'
# ```
#
# * Mean Absolute Error:
#
# ```python
# loss='mae'
# ```
#
# * Huber Loss
#
# ---
#
# ## 7. Optimizers
#
# ### Gradient-Based Optimizers
#
# ```python
# optimizer=keras.optimizers.SGD(
#     learning_rate=0.01,
#     momentum=0.9,
#     nesterov=True
# )
# ```
#
# ```python
# optimizer=keras.optimizers.Adam(
#     learning_rate=0.001,
#     beta_1=0.9,
#     beta_2=0.999,
#     epsilon=1e-7
# )
# ```
#
# Other optimizers:
#
# * RMSprop
# * Adagrad
# * Adadelta
# * AdamW
# * Nadam
# * FTRL
#
# ---
#
# ## 8. Metrics
#
# ```python
# metrics=['accuracy']
# ```
#
# Available metrics:
#
# * Accuracy
# * Precision
# * Recall
# * AUC
# * MeanSquaredError
# * MeanAbsoluteError
#
# ```python
# metrics=[
#     keras.metrics.Precision(),
#     keras.metrics.Recall(),
#     keras.metrics.AUC()
# ]
# ```
#
# ## 9. Regularization Techniques
#
# ### L1 / L2 Regularization
#
# $$ L_{total} = L + \lambda ||W||_p $$
#
# ```python
# kernel_regularizer=keras.regularizers.l2(0.01)
# ```
#
# ### Dropout
#
# ```python
# keras.layers.Dropout(rate=0.5)
# ```
#
# ### Batch Normalization
#
# ```python
# keras.layers.BatchNormalization()
# ```
#
# ## 10. Model Compilation
#
# ```python
# model.compile(
#     optimizer='adam',
#     loss='binary_crossentropy',
#     metrics=['accuracy']
# )
# ```
#
# ## 11. Training the Model
#
# ```python
# model.fit(
#     X_train,
#     y_train,
#     batch_size=32,
#     epochs=100,
#     validation_split=0.2,
#     shuffle=True
# )
# ```
#
# ---
#
# ## 12. Callbacks
#
# ```python
# callbacks=[
#     keras.callbacks.EarlyStopping(patience=10),
#     keras.callbacks.ModelCheckpoint('model.keras'),
#     keras.callbacks.ReduceLROnPlateau()
# ]
# ```
#
# Available callbacks:
#
# * EarlyStopping
# * ModelCheckpoint
# * ReduceLROnPlateau
# * TensorBoard
# * LearningRateScheduler
#
#
# ## 13. Model Evaluation
#
# ```python
# model.evaluate(X_test, y_test)
# ```
#
# ```python
# model.predict(X_new)
# ```
#
# ## 14. Model Summary and Visualization
#
# ```python
# model.summary()
# ```
#
# ```python
# keras.utils.plot_model(model, show_shapes=True)
# ```
#
# ## 15. Saving and Loading Models
#
# ```python
# model.save('model.keras')
# ```
#
# ```python
# model = keras.models.load_model('model.keras')
# ```
#
# ---

# %% [markdown]
# # Example: Classification Problems

# %%
# Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score

# %% [markdown]
# ## Generate Synthetic Data

# %%
# Set random seed for reproducibility
np.random.seed(42)

# Number of samples
n = 1000

# Generate two input features from a standard normal distribution
x1 = np.random.normal(0, 1, n)
x2 = np.random.normal(0, 1, n)

# Generate binary target: points outside a noisy circle are class 1, inside are class 0
y = ((x1**2 + x2**2 + np.random.normal(0, 1, n)) > 1.5).astype(int)

# Combine into a DataFrame for convenience
data = pd.DataFrame({'x1': x1, 'x2': x2, 'y': y})

# %% [markdown]
# ## Visualize the Data

# %%
# Scatter plot of the two classes
plt.figure(figsize=(7,6))
plt.scatter(data[data.y==0].x1, data[data.y==0].x2, color='red', alpha=0.5, label='Class 0')
plt.scatter(data[data.y==1].x1, data[data.y==1].x2, color='blue', alpha=0.5, label='Class 1')
plt.title("Synthetic Data")
plt.xlabel("x1")
plt.ylabel("x2")
plt.legend()
plt.show()

# %% [markdown]
# ## Split Data into Training and Test Sets

# %%
# Split data: 70% train, 30% test
train_data, test_data = train_test_split(data, test_size=0.3, random_state=42, shuffle=True)

# Separate features and target for training and testing
X_train = train_data[['x1', 'x2']].values
y_train = train_data['y'].values
X_test = test_data[['x1', 'x2']].values
y_test = test_data['y'].values

# %% [markdown]
# ## Build the Neural Network Model

# %%
# Build a simple feedforward neural network using Keras Sequential API
model = keras.Sequential([
    keras.layers.Input(shape=(2,)),           # Input layer: 2 features
    keras.layers.Dense(10, activation='sigmoid'),  # Hidden layer: 10 neurons, sigmoid activation
    keras.layers.Dense(1, activation='sigmoid')    # Output layer: 1 neuron, sigmoid activation for binary classification
])

# Print model summary to see architecture
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 10)             │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 41 (164.00 B)
#  Trainable params: 41 (164.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Compile the Model

# %%
# Compile the model with binary crossentropy loss, Adam optimizer, and accuracy metric
model.compile(
    loss='binary_crossentropy',
    optimizer=keras.optimizers.Adam(learning_rate=0.1),
    metrics=['accuracy']
)

# %% [markdown]
# ## Train the Neural Network

# %%
# Train the model on the training data
# epochs: number of times to iterate over the training data
# batch_size: number of samples per gradient update
# verbose=1: show progress bar
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# Epoch 1/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.5244 - loss: 0.7115 - val_accuracy: 0.4533 - val_loss: 0.7136
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.5042 - loss: 0.7024 - val_accuracy: 0.5933 - val_loss: 0.6928
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.6232 - loss: 0.6580 - val_accuracy: 0.6933 - val_loss: 0.6104
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.7363 - loss: 0.5592 - val_accuracy: 0.7600 - val_loss: 0.4974
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7757 - loss: 0.4833 - val_accuracy: 0.8133 - val_loss: 0.4480
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7898 - loss: 0.4375 - val_accuracy: 0.7967 - val_loss: 0.4120
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8236 - loss: 0.4013 - val_accuracy: 0.8400 - val_loss: 0.3901
# Epoch 8/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8285 - loss: 0.3995 - val_accuracy: 0.7967 - val_loss: 0.4132
# Epoch 9/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8114 - loss: 0.4189 - val_accuracy: 0.8133 - val_loss: 0.3953
# Epoch 10/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8289 - loss: 0.3781 - val_accuracy: 0.8267 - val_loss: 0.3976
# Epoch 11/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8230 - loss: 0.4062 - val_accuracy: 0.7967 - val_loss: 0.3984
# Epoch 12/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8036 - loss: 0.4192 - val_accuracy: 0.8133 - val_loss: 0.4108
# Epoch 13/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8380 - loss: 0.3862 - val_accuracy: 0.8267 - val_loss: 0.3925
# Epoch 14/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8150 - loss: 0.4320 - val_accuracy: 0.8300 - val_loss: 0.3914
# Epoch 15/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8329 - loss: 0.4089 - val_accuracy: 0.8433 - val_loss: 0.3962
# Epoch 16/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8299 - loss: 0.3638 - val_accuracy: 0.8167 - val_loss: 0.3950
# Epoch 17/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8203 - loss: 0.3930 - val_accuracy: 0.8067 - val_loss: 0.3990
# Epoch 18/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8299 - loss: 0.3547 - val_accuracy: 0.8067 - val_loss: 0.4039
# Epoch 19/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8115 - loss: 0.4126 - val_accuracy: 0.8100 - val_loss: 0.4024
# Epoch 20/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8224 - loss: 0.4093 - val_accuracy: 0.8333 - val_loss: 0.3934
# Epoch 21/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7989 - loss: 0.4139 - val_accuracy: 0.8367 - val_loss: 0.3949
# Epoch 22/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8328 - loss: 0.3740 - val_accuracy: 0.8300 - val_loss: 0.3937
# Epoch 23/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8018 - loss: 0.3880 - val_accuracy: 0.8233 - val_loss: 0.3964
# Epoch 24/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8278 - loss: 0.3801 - val_accuracy: 0.8000 - val_loss: 0.3990
# Epoch 25/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8262 - loss: 0.3842 - val_accuracy: 0.8000 - val_loss: 0.4097
# Epoch 26/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.7979 - loss: 0.4152 - val_accuracy: 0.7967 - val_loss: 0.4132
# Epoch 27/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8156 - loss: 0.3923 - val_accuracy: 0.8300 - val_loss: 0.4071
# Epoch 28/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8133 - loss: 0.4061 - val_accuracy: 0.8200 - val_loss: 0.3863
# Epoch 29/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8234 - loss: 0.4037 - val_accuracy: 0.8167 - val_loss: 0.4017
# Epoch 30/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8053 - loss: 0.4187 - val_accuracy: 0.8167 - val_loss: 0.4005
# Epoch 31/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8240 - loss: 0.4088 - val_accuracy: 0.8133 - val_loss: 0.3947
# Epoch 32/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8047 - loss: 0.4043 - val_accuracy: 0.8333 - val_loss: 0.4037
# Epoch 33/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8083 - loss: 0.3993 - val_accuracy: 0.8233 - val_loss: 0.4052
# Epoch 34/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8283 - loss: 0.3922 - val_accuracy: 0.8200 - val_loss: 0.3941
# Epoch 35/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8038 - loss: 0.4312 - val_accuracy: 0.7967 - val_loss: 0.4112
# Epoch 36/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8212 - loss: 0.4163 - val_accuracy: 0.8300 - val_loss: 0.3942
# Epoch 37/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8173 - loss: 0.4076 - val_accuracy: 0.8200 - val_loss: 0.3956
# Epoch 38/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7920 - loss: 0.4320 - val_accuracy: 0.8267 - val_loss: 0.3994
# Epoch 39/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7653 - loss: 0.4673 - val_accuracy: 0.8333 - val_loss: 0.3949
# Epoch 40/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7936 - loss: 0.4248 - val_accuracy: 0.8067 - val_loss: 0.3937
# Epoch 41/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8163 - loss: 0.4121 - val_accuracy: 0.8200 - val_loss: 0.3924
# Epoch 42/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8040 - loss: 0.3916 - val_accuracy: 0.8067 - val_loss: 0.4049
# Epoch 43/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8300 - loss: 0.3860 - val_accuracy: 0.8067 - val_loss: 0.4086
# Epoch 44/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8071 - loss: 0.3913 - val_accuracy: 0.8267 - val_loss: 0.3937
# Epoch 45/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8128 - loss: 0.4016 - val_accuracy: 0.8333 - val_loss: 0.4017
# Epoch 46/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8120 - loss: 0.4110 - val_accuracy: 0.8333 - val_loss: 0.3962
# Epoch 47/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8065 - loss: 0.4169 - val_accuracy: 0.8300 - val_loss: 0.3908
# Epoch 48/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8083 - loss: 0.4217 - val_accuracy: 0.8233 - val_loss: 0.4016
# Epoch 49/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8124 - loss: 0.4161 - val_accuracy: 0.8400 - val_loss: 0.3909
# Epoch 50/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7921 - loss: 0.4263 - val_accuracy: 0.8033 - val_loss: 0.4020
# Epoch 51/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8240 - loss: 0.3643 - val_accuracy: 0.7967 - val_loss: 0.4012
# Epoch 52/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8296 - loss: 0.3915 - val_accuracy: 0.8200 - val_loss: 0.3946
# Epoch 53/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7922 - loss: 0.4255 - val_accuracy: 0.8167 - val_loss: 0.3950
# Epoch 54/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8059 - loss: 0.4154 - val_accuracy: 0.8200 - val_loss: 0.3900
# Epoch 55/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8095 - loss: 0.4028 - val_accuracy: 0.8267 - val_loss: 0.3908
# Epoch 56/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8493 - loss: 0.3430 - val_accuracy: 0.8367 - val_loss: 0.3960
# Epoch 57/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8115 - loss: 0.4054 - val_accuracy: 0.8233 - val_loss: 0.3908
# Epoch 58/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8221 - loss: 0.3638 - val_accuracy: 0.8167 - val_loss: 0.4025
# Epoch 59/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8330 - loss: 0.3874 - val_accuracy: 0.8367 - val_loss: 0.3943
# Epoch 60/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8152 - loss: 0.4023 - val_accuracy: 0.8300 - val_loss: 0.3973
# Epoch 61/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8129 - loss: 0.3914 - val_accuracy: 0.8067 - val_loss: 0.4025
# Epoch 62/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8006 - loss: 0.4138 - val_accuracy: 0.8100 - val_loss: 0.4034
# Epoch 63/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8220 - loss: 0.3951 - val_accuracy: 0.8300 - val_loss: 0.4018
# Epoch 64/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8198 - loss: 0.3896 - val_accuracy: 0.8267 - val_loss: 0.3959
# Epoch 65/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8196 - loss: 0.3792 - val_accuracy: 0.8267 - val_loss: 0.4012
# Epoch 66/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8062 - loss: 0.3932 - val_accuracy: 0.8167 - val_loss: 0.3893
# Epoch 67/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8182 - loss: 0.3775 - val_accuracy: 0.8233 - val_loss: 0.4018
# Epoch 68/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8105 - loss: 0.4228 - val_accuracy: 0.8367 - val_loss: 0.3884
# Epoch 69/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8191 - loss: 0.3838 - val_accuracy: 0.8133 - val_loss: 0.3961
# Epoch 70/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8485 - loss: 0.3674 - val_accuracy: 0.8133 - val_loss: 0.3951
# Epoch 71/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8038 - loss: 0.3980 - val_accuracy: 0.8100 - val_loss: 0.3945
# Epoch 72/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.7975 - loss: 0.4157 - val_accuracy: 0.8200 - val_loss: 0.3976
# Epoch 73/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7871 - loss: 0.4224 - val_accuracy: 0.8067 - val_loss: 0.3948
# Epoch 74/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8111 - loss: 0.4148 - val_accuracy: 0.8333 - val_loss: 0.3985
# Epoch 75/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8227 - loss: 0.3980 - val_accuracy: 0.8100 - val_loss: 0.3984
# Epoch 76/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8044 - loss: 0.3974 - val_accuracy: 0.8000 - val_loss: 0.4138
# Epoch 77/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8179 - loss: 0.4224 - val_accuracy: 0.8000 - val_loss: 0.4034
# Epoch 78/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8309 - loss: 0.3739 - val_accuracy: 0.8233 - val_loss: 0.4082
# Epoch 79/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8147 - loss: 0.3926 - val_accuracy: 0.8133 - val_loss: 0.4060
# Epoch 80/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8215 - loss: 0.3685 - val_accuracy: 0.8167 - val_loss: 0.3959
# Epoch 81/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8118 - loss: 0.3858 - val_accuracy: 0.7933 - val_loss: 0.4245
# Epoch 82/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8128 - loss: 0.3963 - val_accuracy: 0.8100 - val_loss: 0.3986
# Epoch 83/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8403 - loss: 0.3654 - val_accuracy: 0.8233 - val_loss: 0.4083
# Epoch 84/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7996 - loss: 0.4050 - val_accuracy: 0.8300 - val_loss: 0.3949
# Epoch 85/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8329 - loss: 0.3670 - val_accuracy: 0.8200 - val_loss: 0.3905
# Epoch 86/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8167 - loss: 0.4025 - val_accuracy: 0.8233 - val_loss: 0.3919
# Epoch 87/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8068 - loss: 0.3967 - val_accuracy: 0.8133 - val_loss: 0.4030
# Epoch 88/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8112 - loss: 0.3864 - val_accuracy: 0.8167 - val_loss: 0.3921
# Epoch 89/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7898 - loss: 0.4163 - val_accuracy: 0.8100 - val_loss: 0.3902
# Epoch 90/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8160 - loss: 0.3889 - val_accuracy: 0.8333 - val_loss: 0.4050
# Epoch 91/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8209 - loss: 0.3843 - val_accuracy: 0.8100 - val_loss: 0.3954
# Epoch 92/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8348 - loss: 0.3764 - val_accuracy: 0.8233 - val_loss: 0.3923
# Epoch 93/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7944 - loss: 0.4086 - val_accuracy: 0.8233 - val_loss: 0.3963
# Epoch 94/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8004 - loss: 0.3881 - val_accuracy: 0.8267 - val_loss: 0.3937
# Epoch 95/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8130 - loss: 0.3852 - val_accuracy: 0.8200 - val_loss: 0.3869
# Epoch 96/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7975 - loss: 0.4100 - val_accuracy: 0.8200 - val_loss: 0.3948
# Epoch 97/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7866 - loss: 0.4133 - val_accuracy: 0.8200 - val_loss: 0.3990
# Epoch 98/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8281 - loss: 0.3676 - val_accuracy: 0.8133 - val_loss: 0.3959
# Epoch 99/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7971 - loss: 0.4099 - val_accuracy: 0.8267 - val_loss: 0.3872
# Epoch 100/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8144 - loss: 0.4010 - val_accuracy: 0.8033 - val_loss: 0.3997

# %% [markdown]
# ## Plot Training and Validation Accuracy and Loss

# %%
# Plot accuracy and loss curves for training and validation
fig, ax = plt.subplots(1, 2, figsize=(14,5))

# Plot accuracy
ax[0].plot(history.history['accuracy'], label='Train Accuracy')
ax[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
ax[0].set_title('Accuracy over Epochs')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Accuracy')
ax[0].legend()
ax[0].grid(True, alpha=0.3)

# Plot loss
ax[1].plot(history.history['loss'], label='Train Loss')
ax[1].plot(history.history['val_loss'], label='Validation Loss')
ax[1].set_title('Loss over Epochs')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Loss')
ax[1].legend()
ax[1].grid(True, alpha=0.3)

plt.show()

# %% [markdown]
# ## Evaluate the Model on Test Data

# %%
# Predict probabilities on test set
y_pred_prob = model.predict(X_test, verbose=0)

# Convert probabilities to binary class predictions (threshold 0.5)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()

# Compute confusion matrix and accuracy
cm = confusion_matrix(y_test, y_pred)
acc = accuracy_score(y_test, y_pred)
print("Confusion Matrix:\n", cm)
print(f"Accuracy: {acc:.4f}")
# Out:
# Confusion Matrix:
#  [[118  31]
#  [ 28 123]]
# Accuracy: 0.8033

# %% [markdown]
# ## Plot Decision Boundary

# %%
# Create a mesh grid for plotting the decision boundary
x1_min, x1_max = data.x1.min() - 0.5, data.x1.max() + 0.5
x2_min, x2_max = data.x2.min() - 0.5, data.x2.max() + 0.5
xx1, xx2 = np.meshgrid(np.linspace(x1_min, x1_max, 200),
                       np.linspace(x2_min, x2_max, 200))
grid_points = np.c_[xx1.ravel(), xx2.ravel()]

# Predict probabilities for each point in the grid
grid_pred_prob = model.predict(grid_points)
grid_pred = (grid_pred_prob > 0.5).astype(int).reshape(xx1.shape)

# Plot the decision boundary and data points
plt.figure(figsize=(8,6))
plt.scatter(data[data.y==0].x1, data[data.y==0].x2, color='red', alpha=0.5, label='Class 0')
plt.scatter(data[data.y==1].x1, data[data.y==1].x2, color='blue', alpha=0.5, label='Class 1')
plt.contour(xx1, xx2, grid_pred, levels=[0.5], colors='k', linewidths=2)
plt.title("Decision Boundary of the Neural Network")
plt.xlabel("x1")
plt.ylabel("x2")
plt.legend()
plt.show()
# Out:
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step

# %% [markdown]
# ## Conclusion
#
# In this notebook, we constructed a basic neural network for binary classification using TensorFlow/Keras. We covered the essential components of neural networks and demonstrated how to train and evaluate a neural network on synthetic data. The model's decision boundary was visualized to understand how it classifies the data. Remarkably, the results look very similar to what we achieved in when we code our NNs from scratch.
